# %% [markdown]
# a

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
# Replace 'your_dataset.csv' with the actual path to your CSV file
mortality_data = pd.read_csv('cleaned_dataset_20251104_200505.csv')

# Display the first few rows to verify the data is loaded correctly
mortality_data.head()
# Out:
# La ejecución de celdas con 'mortality-ami-env (Python 3.11.14)' requiere el paquete ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crear un entorno de Python</a> con los paquetes necesarios.
#
# O instale "ipykernel" mediante el comando: "conda install -n mortality-ami-env ipykernel --update-deps --force-reinstall"
